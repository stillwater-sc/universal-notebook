// %% [markdown]
// # Tutorial \#1: Hello World

// %% [markdown]
// The Universal library is a ready-to-use header-only library that provides plug-in replacement for native types, and provides a low-friction environment to start exploring alternatives to IEEE floating-point in your own algorithms. In order to use it in this online environment you need to first import the global header file:

// %%
#include "universal.hpp"
#include <universal/number/posit/posit>

// %% [markdown]
// The basic use pattern is as simple as:

// %%
sw::universal::posit<32,2> a(2.2);
// Out:
// /home/jovyan/universal/include/universal/number/posit/posit.hpp:1160:27: error: call to constructor of 'internal::value<dfbits>' is ambiguous
//                 internal::value<dfbits> v(static_cast<T>(rhs));
//                                         ^ ~~~~~~~~~~~~~~~~~~~
// /home/jovyan/universal/include/universal/number/posit/posit.hpp:615:13: note: in instantiation of function template specialization 'sw::universal::posit<32, 2>::float_assign<double>' requested here
//             float_assign(rhs);
//             ^
// /home/jovyan/universal/include/universal/number/posit/posit.hpp:497:60: note: in instantiation of member function 'sw::universal::posit<32, 2>::operator=' requested here
//         constexpr posit(double initial_value)             { *this = initial_value; }
//                                                                   ^
// input_line_13:2:29: note: in instantiation of member function 'sw::universal::posit<32, 2>::posit' requested here
// ...
